# %%
import pandas as pd
from datetime import datetime

# %%
df=pd.read_csv("/content/ADANIPORTS.csv")

# %%
df.head()
# Out:
#          Date      Symbol Series  Prev Close    Open     High    Low   Last  \
# 0  2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.0  959.0
# 1  2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.0  885.0
# 2  2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.0  887.0
# 3  2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.0  929.0
# 4  2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.0  980.0
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  962.90  984.72  27294366  2.687719e+15     NaN             9859619
# 1  893.90  941.38   4581338  4.312765e+14     NaN             1453278
# 2  884.20  888.09   5124121  4.550658e+14     NaN             1069678
# 3  921.55  929.17   4609762  4.283257e+14     NaN             1260913
# 4  969.30  965.65   2977470  2.875200e+14     NaN              816123
#
#    %Deliverble
# 0       0.3612
# 1       0.3172
# 2       0.2088
# 3       0.2735
# ...

# %%
df.tail()
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 2988  2019-12-24  ADANIPORTS     EQ      366.90  368.00  372.00  366.00
# 2989  2019-12-26  ADANIPORTS     EQ      368.60  368.80  370.60  362.10
# 2990  2019-12-27  ADANIPORTS     EQ      363.65  366.75  367.90  362.80
# 2991  2019-12-30  ADANIPORTS     EQ      363.70  371.00  371.00  363.75
# 2992  2019-12-31  ADANIPORTS     EQ      365.95  366.00  368.65  364.90
#
#         Last   Close    VWAP   Volume      Turnover   Trades  \
# 2988  368.50  368.60  368.88  2948878  1.087779e+14  45244.0
# 2989  362.10  363.65  366.52  2503435  9.175530e+13  33520.0
# 2990  363.85  363.70  365.19  2146972  7.840569e+13  30299.0
# 2991  366.00  365.95  366.81  4732203  1.735840e+14  45583.0
# 2992  366.20  366.00  366.52  2043206  7.488704e+13  16901.0
#
#       Deliverable Volume  %Deliverble
# 2988             1063340       0.3606
# 2989              774317       0.3093
# 2990              445974       0.2077
# ...

# %%
df.set_index('Date',inplace=True)

# %%
df.index
# Out:
# Index(['2007-11-27', '2007-11-28', '2007-11-29', '2007-11-30', '2007-12-03',
#        '2007-12-04', '2007-12-05', '2007-12-06', '2007-12-07', '2007-12-10',
#        ...
#        '2019-12-17', '2019-12-18', '2019-12-19', '2019-12-20', '2019-12-23',
#        '2019-12-24', '2019-12-26', '2019-12-27', '2019-12-30', '2019-12-31'],
#       dtype='object', name='Date', length=2993)

# %%
Index=df.loc['2018-12-17':'2019-12-17'].index
share_open=df.loc['2018-12-17':'2019-12-17']['Open']
share_open
# Out:
# Date
# 2018-12-17    369.15
# 2018-12-18    369.00
# 2018-12-19    373.90
# 2018-12-20    374.20
# 2018-12-21    374.30
#                ...
# 2019-12-11    368.95
# 2019-12-12    371.45
# 2019-12-13    372.55
# 2019-12-16    377.25
# 2019-12-17    369.20
# Name: Open, Length: 246, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
figure,axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(Index,share_open)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2993 entries, 2007-11-27 to 2019-12-31
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2993 non-null   object
#  1   Series              2993 non-null   object
#  2   Prev Close          2993 non-null   float64
#  3   Open                2993 non-null   float64
#  4   High                2993 non-null   float64
#  5   Low                 2993 non-null   float64
#  6   Last                2993 non-null   float64
#  7   Close               2993 non-null   float64
#  8   VWAP                2993 non-null   float64
#  9   Volume              2993 non-null   int64
#  10  Turnover            2993 non-null   float64
#  11  Trades              2126 non-null   float64
#  12  Deliverable Volume  2993 non-null   int64
#  13  %Deliverble         2993 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 415.3+ KB

# %%
#datetime

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 11, 20, 23, 44, 49, 777109)

# %%
date=datetime(2023,11,20)

# %%
date
# Out:
# datetime.datetime(2023, 11, 20, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2023, 11, 20)

# %%
date.day
# Out:
# 20

# %%
date.weekday()
# Out:
# 0

# %%
date.year
# Out:
# 2023

# %%
date.month
# Out:
# 11

# %%
#TimeResampling

# %%
df.head()
# Out:
#                 Symbol Series  Prev Close    Open     High    Low   Last  \
# Date
# 2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.0  959.0
# 2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.0  885.0
# 2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.0  887.0
# 2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.0  929.0
# 2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.0  980.0
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2007-11-27  962.90  984.72  27294366  2.687719e+15     NaN
# 2007-11-28  893.90  941.38   4581338  4.312765e+14     NaN
# 2007-11-29  884.20  888.09   5124121  4.550658e+14     NaN
# 2007-11-30  921.55  929.17   4609762  4.283257e+14     NaN
# 2007-12-03  969.30  965.65   2977470  2.875200e+14     NaN
#
#             Deliverable Volume  %Deliverble
# Date
# 2007-11-27             9859619       0.3612
# 2007-11-28             1453278       0.3172
# ...

# %%
df.index=pd.to_datetime(df.index)
df.resample(rule='A').min()
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2007-12-31  MUNDRAPORT     EQ      440.00  770.00  914.75  770.00  885.00
# 2008-12-31  MUNDRAPORT     EQ      257.95  257.00  262.55  253.65  257.75
# 2009-12-31  MUNDRAPORT     EQ      297.90  290.00  304.50  290.00  295.85
# 2010-12-31  MUNDRAPORT     EQ      137.75  137.65  142.65  114.00  138.30
# 2011-12-31  MUNDRAPORT     EQ      117.70  110.00  123.60  110.00  117.50
# 2012-12-31  ADANIPORTS     EQ      108.00  108.00  110.45  105.65  108.00
# 2013-12-31  ADANIPORTS     EQ      121.95  118.70  124.80  116.65  121.70
# 2014-12-31  ADANIPORTS     EQ      141.65  142.50  146.35  141.00  142.40
# 2015-12-31  ADANIPORTS     EQ      241.15  239.80  249.45  238.75  241.30
# 2016-12-31  ADANIPORTS     EQ      171.55  171.60  180.40  169.15  170.90
# 2017-12-31  ADANIPORTS     EQ      268.45  269.80  276.90  267.00  274.00
# 2018-12-31  ADANIPORTS     EQ      301.80  301.80  305.60  294.10  298.00
# ...

# %%
df.resample(rule='M').max()
# Out:
#                 Symbol Series  Prev Close     Open     High      Low    Last  \
# Date
# 2007-11-30  MUNDRAPORT     EQ      962.90   984.00  1050.00   890.00   959.0
# 2007-12-31  MUNDRAPORT     EQ     1249.10  1263.35  1295.00  1261.00  1270.0
# 2008-01-31  MUNDRAPORT     EQ     1307.45  1310.25  1324.00  1270.00  1308.0
# 2008-02-29  MUNDRAPORT     EQ      856.10   856.00   872.40   840.00   859.0
# 2008-03-31  MUNDRAPORT     EQ      735.65   725.00   725.00   692.30   698.1
# ...                ...    ...         ...      ...      ...      ...     ...
# 2019-08-31  ADANIPORTS     EQ      377.55   379.55   380.50   374.25   377.3
# 2019-09-30  ADANIPORTS     EQ      419.15   418.00   420.60   412.00   418.3
# 2019-10-31  ADANIPORTS     EQ      421.70   421.50   428.85   417.10   422.2
# 2019-11-30  ADANIPORTS     EQ      395.80   396.00   397.25   389.75   391.5
# 2019-12-31  ADANIPORTS     EQ      382.05   381.10   383.35   375.85   377.7
#
# ...

# %%
df.resample(rule='A').max()
# Out:
#                 Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2007-12-31  MUNDRAPORT     EQ     1249.10  1263.35  1295.00  1261.00  1270.00
# 2008-12-31  MUNDRAPORT     EQ     1307.45  1310.25  1324.00  1270.00  1308.00
# 2009-12-31  MUNDRAPORT     EQ      687.40   697.70   705.00   656.25   684.50
# 2010-12-31  MUNDRAPORT     EQ      848.10   849.00   857.40   835.00   847.90
# 2011-12-31  MUNDRAPORT     EQ      165.00   165.05   170.45   163.55   165.40
# 2012-12-31  MUNDRAPORT     EQ      155.40   155.75   157.75   150.65   155.40
# 2013-12-31  ADANIPORTS     EQ      168.25   169.70   175.00   166.90   168.90
# 2014-12-31  ADANIPORTS     EQ      316.00   316.80   321.30   311.40   320.00
# 2015-12-31  ADANIPORTS     EQ      368.55   366.95   374.80   361.65   370.00
# 2016-12-31  ADANIPORTS     EQ      312.80   312.95   317.00   304.00   310.65
# 2017-12-31  ADANIPORTS     EQ      437.55   438.65   443.30   432.75   437.50
# ...

# %%
df.resample(rule='A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample(rule='BA').max()
# Out:
#                 Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2007-12-31  MUNDRAPORT     EQ     1249.10  1263.35  1295.00  1261.00  1270.00
# 2008-12-31  MUNDRAPORT     EQ     1307.45  1310.25  1324.00  1270.00  1308.00
# 2009-12-31  MUNDRAPORT     EQ      687.40   697.70   705.00   656.25   684.50
# 2010-12-31  MUNDRAPORT     EQ      848.10   849.00   857.40   835.00   847.90
# 2011-12-30  MUNDRAPORT     EQ      165.00   165.05   170.45   163.55   165.40
# 2012-12-31  MUNDRAPORT     EQ      155.40   155.75   157.75   150.65   155.40
# 2013-12-31  ADANIPORTS     EQ      168.25   169.70   175.00   166.90   168.90
# 2014-12-31  ADANIPORTS     EQ      316.00   316.80   321.30   311.40   320.00
# 2015-12-31  ADANIPORTS     EQ      368.55   366.95   374.80   361.65   370.00
# 2016-12-30  ADANIPORTS     EQ      312.80   312.95   317.00   304.00   310.65
# 2017-12-29  ADANIPORTS     EQ      437.55   438.65   443.30   432.75   437.50
# ...

# %%
df.resample(rule='BQS').max()
# Out:
#                 Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2007-10-01  MUNDRAPORT     EQ     1249.10  1263.35  1295.00  1261.00  1270.00
# 2008-01-01  MUNDRAPORT     EQ     1307.45  1310.25  1324.00  1270.00  1308.00
# 2008-04-01  MUNDRAPORT     EQ      901.35   909.90   926.00   869.80   902.00
# 2008-07-01  MUNDRAPORT     EQ      626.50   620.00   637.00   607.00   626.50
# 2008-10-01  MUNDRAPORT     EQ      436.00   434.00   472.00   426.00   437.00
# 2009-01-01  MUNDRAPORT     EQ      395.20   400.00   408.90   383.00   395.20
# 2009-04-01  MUNDRAPORT     EQ      687.40   697.70   705.00   656.25   684.50
# 2009-07-01  MUNDRAPORT     EQ      607.80   613.85   624.00   595.30   608.00
# 2009-10-01  MUNDRAPORT     EQ      573.75   573.00   584.80   567.05   574.70
# 2010-01-01  MUNDRAPORT     EQ      786.60   789.00   799.80   785.00   788.10
# 2010-04-01  MUNDRAPORT     EQ      789.60   789.40   806.00   773.55   784.00
# ...
